# %% [markdown]
# ## Trying to fix the plotting issue with new sheet.

# %%
# This line will make all matplotlib graphs to appear in the notebook only.
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();  # We can see the [] disappear now.

# %%
# We will get same result for plt.show and plt.plot

plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4])

# %%
# plotting from data by creating arrays of x and y
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y)
plt.show();

# %%
plt.plot()  # sort of refreshing the result.
plt.show();

# %%
# Different methods in creating the plots
fig = plt.figure()  # Creates a figure
ax = fig.add_subplot()  # Adds some axes
plt.show();

# %%
# 2nd method
fig = plt.figure()  # Create a figure
ax = fig.add_axes([1, 1, 1, 1])  # add some data
print(x, y)
ax.plot(x, y)
plt.show();
# Out:
# [1, 2, 3, 4] [11, 22, 33, 44]

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()  # This will resets the figure
print(x, y)
ax.plot(x, y)
plt.show();
# Out:
# [1, 2, 3, 4] [11, 22, 33, 44]

# %%
# 3rd method with some data
fig, ax = plt.subplots()  # resets the figure
ax.plot([x, [100, 170, 210, 290]]);  # adds some data
type(fig), type(ax)
plt.show();

# %% [markdown]
# ### Matplotlib example workflow

# %%
# 0. Import matplotlib and get it ready for plotting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10))  # (width, height)

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Simple Plot",
       xlabel="x-axis",
       ylabel="y-axis")

# 5. Save and show (you save the whole figure)
fig.savefig("sample-plot2.png")

# %% [markdown]
# ### Making figures with NumPy arrays
#
# we want
#
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Create some data
x = np.linspace(0, 10, 100)  # return evenly spaced numbers between 0 to 10 of 100 in numbers
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2)
plt.show();

# %%
# using the same data to make a scatter plot
fig, ax = plt.subplots()
print(x)
ax.scatter(x, np.sin(x))
plt.show();
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
#   7.87878788  7.97979798  8.08080808  8.18181818  8.28282828  8.38383838
#   8.48484848  8.58585859  8.68686869  8.78787879  8.88888889  8.98989899
#   9.09090909  9.19191919  9.29292929  9.39393939  9.49494949  9.5959596
#   9.6969697   9.7979798   9.8989899  10.        ]

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))
plt.show();

# %%
# Make a plot from a dictionary
nut_butter_prices = {"Almond Butter" : 10,
                     "Peanut Butter" : 8,
                     "Cashew Butter" : 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Nut Butter Store",
       ylabel="Price($)")
plt.show();

# %%
fig, ax = plt.subplots()
ax.barh(nut_butter_prices.keys(), nut_butter_prices.values())  # horizontal bar representation. 
ax.set(title="Nut Butter Store",
       xlabel="Price($)")
plt.show();

# %%
# Random histograms
x = np.random.randn(1000)  # normal distribution.
fig, ax = plt.subplots()
ax.hist(x)
plt.show();

# %% [markdown]
# ### Two options for subplots

# %%
# subplot option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10, 5))

# plot to each different axis
ax1.plot(x, x / 2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
plt.show();

# %%
# Subplots option 2
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10, 5))
# plot to each different index
ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000))
plt.show();

# %% [markdown]
# ## Plotting from Pandas DataFrame

# %%
import pandas as pd

# %%
# Make a dataframe
car_sales = pd.read_csv("car-sales-custom.csv")
car_sales[:10]
# Out:
#      Make       Colour  Odometer (KM)  Doors       Price
# 0  Nissan  CanyonRidge         161431      3   $8,913.62
# 1     BMW        Green         242890      5  $19,283.08
# 2    Ford  CanyonRidge         174387      5   $9,155.99
# 3   Honda  CanyonRidge          44283      3   $8,269.27
# 4   Honda         Blue         147422      3   $7,367.80
# 5  Nissan  CanyonRidge         156277      3   $9,801.71
# 6  Nissan        White         198372      5   $8,786.15
# 7     BMW          Red         197485      3  $21,463.86
# 8    Ford        Black         231364      3  $11,778.96
# 9  Toyota        White         190834      4   $6,773.88

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range("1/1/2020", periods=1000))
ts = ts.cumsum()
ts.plot()
plt.show();

# %%
car_sales['Price'] = car_sales['Price'].replace('[\\$\\,\\.]', '', regex=True).astype(int)
car_sales[:10]
# Out:
#      Make       Colour  Odometer (KM)  Doors    Price
# 0  Nissan  CanyonRidge         161431      3   891362
# 1     BMW        Green         242890      5  1928308
# 2    Ford  CanyonRidge         174387      5   915599
# 3   Honda  CanyonRidge          44283      3   826927
# 4   Honda         Blue         147422      3   736780
# 5  Nissan  CanyonRidge         156277      3   980171
# 6  Nissan        White         198372      5   878615
# 7     BMW          Red         197485      3  2146386
# 8    Ford        Black         231364      3  1177896
# 9  Toyota        White         190834      4   677388

# %%
type(car_sales['Price'][0])
# Out:
# numpy.int64

# %%
car_sales['Price'] = (car_sales['Price'] / 100).astype(int)
car_sales[:10]
# Out:
#      Make       Colour  Odometer (KM)  Doors  Price
# 0  Nissan  CanyonRidge         161431      3   8913
# 1     BMW        Green         242890      5  19283
# 2    Ford  CanyonRidge         174387      5   9155
# 3   Honda  CanyonRidge          44283      3   8269
# 4   Honda         Blue         147422      3   7367
# 5  Nissan  CanyonRidge         156277      3   9801
# 6  Nissan        White         198372      5   8786
# 7     BMW          Red         197485      3  21463
# 8    Ford        Black         231364      3  11778
# 9  Toyota        White         190834      4   6773

# %%
# Adding a new column
car_sales['Sale Date'] = pd.date_range('1/1/1920', periods=len(car_sales))
car_sales[:10]
# Out:
#      Make       Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Nissan  CanyonRidge         161431      3   8913 1920-01-01
# 1     BMW        Green         242890      5  19283 1920-01-02
# 2    Ford  CanyonRidge         174387      5   9155 1920-01-03
# 3   Honda  CanyonRidge          44283      3   8269 1920-01-04
# 4   Honda         Blue         147422      3   7367 1920-01-05
# 5  Nissan  CanyonRidge         156277      3   9801 1920-01-06
# 6  Nissan        White         198372      5   8786 1920-01-07
# 7     BMW          Red         197485      3  21463 1920-01-08
# 8    Ford        Black         231364      3  11778 1920-01-09
# 9  Toyota        White         190834      4   6773 1920-01-10

# %%
# making cumsum of sales
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales[:10]
# Out:
#      Make       Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Nissan  CanyonRidge         161431      3   8913 1920-01-01         8913
# 1     BMW        Green         242890      5  19283 1920-01-02        28196
# 2    Ford  CanyonRidge         174387      5   9155 1920-01-03        37351
# 3   Honda  CanyonRidge          44283      3   8269 1920-01-04        45620
# 4   Honda         Blue         147422      3   7367 1920-01-05        52987
# 5  Nissan  CanyonRidge         156277      3   9801 1920-01-06        62788
# 6  Nissan        White         198372      5   8786 1920-01-07        71574
# 7     BMW          Red         197485      3  21463 1920-01-08        93037
# 8    Ford        Black         231364      3  11778 1920-01-09       104815
# 9  Toyota        White         190834      4   6773 1920-01-10       111588

# %%
# Lets plot the total sales
car_sales.plot(x='Sale Date', y='Total Sales')
plt.show();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
plt.show();
