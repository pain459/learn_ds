# %% [markdown]
# ## Trying to fix the plotting issue with new sheet.

# %%
# This line will make all matplotlib graphs to appear in the notebook only.
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();  # We can see the [] disappear now.

# %%
# We will get same result for plt.show and plt.plot

plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4])

# %%
# plotting from data by creating arrays of x and y
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y)
plt.show();

# %%
plt.plot()  # sort of refreshing the result.
plt.show();

# %%
# Different methods in creating the plots
fig = plt.figure()  # Creates a figure
ax = fig.add_subplot()  # Adds some axes
plt.show();

# %%
# 2nd method
fig = plt.figure()  # Create a figure
ax = fig.add_axes([1, 1, 1, 1])  # add some data
print(x, y)
ax.plot(x, y)
plt.show();
# Out:
# [1, 2, 3, 4] [11, 22, 33, 44]

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()  # This will resets the figure
print(x, y)
ax.plot(x, y)
plt.show();
# Out:
# [1, 2, 3, 4] [11, 22, 33, 44]

# %%
# 3rd method with some data
fig, ax = plt.subplots()  # resets the figure
ax.plot([x, [100, 170, 210, 290]]);  # adds some data
type(fig), type(ax)
plt.show();

# %% [markdown]
# ### Matplotlib example workflow

# %%
# 0. Import matplotlib and get it ready for plotting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10))  # (width, height)

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Simple Plot",
       xlabel="x-axis",
       ylabel="y-axis")

# 5. Save and show (you save the whole figure)
fig.savefig("sample-plot2.png")

# %% [markdown]
# ### Making figures with NumPy arrays
#
# we want
#
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Create some data
x = np.linspace(0, 10, 100)  # return evenly spaced numbers between 0 to 10 of 100 in numbers
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2)
plt.show();

# %%
# using the same data to make a scatter plot
fig, ax = plt.subplots()
print(x)
ax.scatter(x, np.sin(x))
plt.show();
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))
plt.show();

# %%
# Make a plot from a dictionary
nut_butter_prices = {"Almond Butter" : 10,
                     "Peanut Butter" : 8,
                     "Cashew Butter" : 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Nut Butter Store",
       ylabel="Price($)")
plt.show();

# %%
fig, ax = plt.subplots()
ax.barh(nut_butter_prices.keys(), nut_butter_prices.values())  # horizontal bar representation. 
ax.set(title="Nut Butter Store",
       xlabel="Price($)")
plt.show();

# %%
# Random histograms
x = np.random.randn(1000)  # normal distribution.
fig, ax = plt.subplots()
ax.hist(x)
plt.show();

# %% [markdown]
# ### Two options for subplots

# %%
# subplot option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10, 5))

# plot to each different axis
ax1.plot(x, x / 2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
plt.show();

# %%
# Subplots option 2
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10, 5))
# plot to each different index
ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000))
plt.show();

# %% [markdown]
# ## Plotting from Pandas DataFrame

# %%
import pandas as pd

# %%
# Make a dataframe
car_sales = pd.read_csv("car-sales-custom.csv")
car_sales[:10]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range("1/1/2020", periods=1000))
ts = ts.cumsum()
ts.plot()
plt.show();

# %%
car_sales['Price'] = car_sales['Price'].replace('[\\$\\,\\.]', '', regex=True).astype(int)
car_sales[:10]
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales['Price'][0])
# Out:
# numpy.int64

# %%
car_sales['Price'] = (car_sales['Price'] / 100).astype(int)
car_sales[:10]
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Adding a new column
car_sales['Sale Date'] = pd.date_range('1/1/1920', periods=len(car_sales))
car_sales[:10]
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 1920-01-01
# 1   Honda    Red          87899      4   5000 1920-01-02
# 2  Toyota   Blue          32549      3   7000 1920-01-03
# 3     BMW  Black          11179      5  22000 1920-01-04
# 4  Nissan  White         213095      4   3500 1920-01-05
# 5  Toyota  Green          99213      4   4500 1920-01-06
# 6   Honda   Blue          45698      4   7500 1920-01-07
# 7   Honda   Blue          54738      4   7000 1920-01-08
# 8  Toyota  White          60000      4   6250 1920-01-09
# 9  Nissan  White          31600      4   9700 1920-01-10

# %%
# making cumsum of sales
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales[:10]
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 1920-01-01         4000
# 1   Honda    Red          87899      4   5000 1920-01-02         9000
# 2  Toyota   Blue          32549      3   7000 1920-01-03        16000
# 3     BMW  Black          11179      5  22000 1920-01-04        38000
# 4  Nissan  White         213095      4   3500 1920-01-05        41500
# 5  Toyota  Green          99213      4   4500 1920-01-06        46000
# 6   Honda   Blue          45698      4   7500 1920-01-07        53500
# 7   Honda   Blue          54738      4   7000 1920-01-08        60500
# 8  Toyota  White          60000      4   6250 1920-01-09        66750
# 9  Nissan  White          31600      4   9700 1920-01-10        76450

# %%
# Lets plot the total sales
car_sales.plot(x='Sale Date', y='Total Sales')
plt.show();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
plt.show();

# %%
# How about a bar graph?
x = np.random.randn(10, 4)
x

# Turn it into a dataframe
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -0.234953 -0.446522  0.130815 -1.410911
# 1 -1.051915 -0.612363 -0.323601  0.682855
# 2 -0.433505  0.178627  1.092856  0.311370
# 3  0.318548  1.081311  1.690108  1.358018
# 4  1.853686  0.819125  0.522427  1.022822
# 5 -0.621769 -0.724113  0.277166  0.702764
# 6  0.853086 -1.380536  0.808705 -0.306718
# 7  0.612794 -1.026629  1.053225  0.677798
# 8  1.641379  0.764046 -0.070484 -0.993679
# 9  0.630898 -0.429047 -1.690248 -1.431929

# %%
df.plot.bar()
plt.show();

# %%
df.plot(kind='bar')  # We get the same exact plot.
plt.show();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 1920-01-01         4000
# 1   Honda    Red          87899      4   5000 1920-01-02         9000
# 2  Toyota   Blue          32549      3   7000 1920-01-03        16000
# 3     BMW  Black          11179      5  22000 1920-01-04        38000
# 4  Nissan  White         213095      4   3500 1920-01-05        41500
# 5  Toyota  Green          99213      4   4500 1920-01-06        46000
# 6   Honda   Blue          45698      4   7500 1920-01-07        53500
# 7   Honda   Blue          54738      4   7000 1920-01-08        60500
# 8  Toyota  White          60000      4   6250 1920-01-09        66750
# 9  Nissan  White          31600      4   9700 1920-01-10        76450

# %%
car_sales.plot(x='Make', y='Odometer (KM)', kind='bar')
plt.show();

# %%
# how about histograms?

car_sales['Odometer (KM)'].plot.hist()  # default bin is 10. We can change it later.
plt.show();

# %%
car_sales['Odometer (KM)'].plot(kind='hist')
plt.show();

# %%
car_sales['Odometer (KM)'].plot.hist(bins=20)  # We can adjust he bin size.
plt.show();

# %%
# Lets try on another dataset

heart_disease = pd.read_csv('heart-disease.csv')
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# create a historgram of age
heart_disease['age'].plot.hist(bins=10)
plt.show();

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(subplots=True)
plt.show();

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True)  # Adjusting for visibility
plt.show();

# %% [markdown]
# ### Which one should you use ? (pyplot vs matplotlib OO method?)
#
# * When plotting something quickly, okay to use the pyplot method.
# * When plotting something more advanced, use the OO method.

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
len(over_50)
# Out:
# 208

# %%
# Pyplot method
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             figsize=(10, 6))
plt.show();

# %%
# OO method mixed with pyplot method.
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax)
# ax.set_xlim([45, 100])  # this is to set the x axis limits.
plt.show();

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'])

# Customize the plot
ax.set(title='Heart Disease and CHolesterol Levels',
       xlabel='Age',
       ylabel='Cholesterol')

# Add a legend

ax.legend(*scatter.legend_elements(), title='Target')

# Add horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle="--")
plt.show();

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplot of chol, age and thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10, 10))

# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"])
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        xlabel="Age",
        ylabel="Cholesterol")

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title='Target')
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle='--')

# --- new graph using thalach --- #

# Add data to ax0
scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"])
# Customize ax0
ax1.set(title="Heart Disease and Max Heart Rate",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Add a legend to ax0
ax1.legend(*scatter.legend_elements(), title='Target')
# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle='--')

# Add title to the fugire
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")

plt.show();

# %% [markdown]
# ## Customizing Matplotlib plots and getting stylish

# %%
## Customizing the plots
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 1920-01-01         4000
# 1   Honda    Red          87899      4   5000 1920-01-02         9000
# 2  Toyota   Blue          32549      3   7000 1920-01-03        16000
# 3     BMW  Black          11179      5  22000 1920-01-04        38000
# 4  Nissan  White         213095      4   3500 1920-01-05        41500

# %%
car_sales["Price"].plot()
plt.show();

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
car_sales['Price'].plot()
plt.show();

# %%
plt.style.use('seaborn-v0_8')

# %%
car_sales["Price"].plot()
plt.show();

# %%
car_sales.plot(x='Odometer (KM)', y='Price', kind='scatter')
plt.show();

# %%
plt.style.use('ggplot')
car_sales['Price'].plot()
plt.show();

# %%
# Create some data
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.89934094, -1.41828118,  0.40015049, -1.75657892],
#        [-0.52689643,  1.38601951,  1.92074491,  0.18846339],
#        [ 0.24745901, -1.07046235,  1.2689622 , -0.40673509],
#        [ 0.97541137, -2.80719399,  0.91783155,  0.83920186],
#        [ 0.16907332,  0.81192242, -1.33957352, -1.76331648],
#        [-0.81619165,  0.44813396, -0.92042901, -0.81262169],
#        [-0.13980061,  1.2002793 ,  1.58888588,  1.97057749],
#        [ 0.31694225,  0.55168947,  1.19003579,  0.21529213],
#        [-0.94948854, -1.39446734, -1.31657108,  0.51411825],
#        [ 2.31890532, -1.18524845, -0.00446614,  0.15413952]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.899341 -1.418281  0.400150 -1.756579
# 1 -0.526896  1.386020  1.920745  0.188463
# 2  0.247459 -1.070462  1.268962 -0.406735
# 3  0.975411 -2.807194  0.917832  0.839202
# 4  0.169073  0.811922 -1.339574 -1.763316
# 5 -0.816192  0.448134 -0.920429 -0.812622
# 6 -0.139801  1.200279  1.588886  1.970577
# 7  0.316942  0.551689  1.190036  0.215292
# 8 -0.949489 -1.394467 -1.316571  0.514118
# 9  2.318905 -1.185248 -0.004466  0.154140

# %%
ax = df.plot(kind='bar')
plt.show();
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
# Customize our plt with the set() method
ax = df.plot(kind='bar')
# Add some labels and a title
ax.set(title='Random Number Bar Graph from DataFrame',
       xlabel='Row Number',
       ylabel='Random Number')
# Make thje legend visible
ax.legend().set_visible(True)
plt.show();
